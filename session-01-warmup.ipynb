# %%
print("Hello")
# Out:
# Hello

# %%
name=("Swamini Ektate")
print (name)
# Out:
# Swamini Ektate

# %% [markdown]
# ## AI Prompts Used
#
# **Part A prompt:**
# Write a Python script in a Jupyter Notebook that:
# - Creates two integer variables with values of my choice
# - Adds them together
# - Prints the result with a clear message such as 'The sum is X'
# Use clear variable names and good naming conventions.

# %%
# Author: Swamini Prashant Ektate
# Module: Data Analytics and Machine Learning, Hult
# Date: 5th May 2026
# Sources: Claude (Anthropic) used to generate initial structure; reviewed and understood by author

# Part A: Adding two integers

first_number = 15
second_number = 27

total_sum = first_number + second_number

print("The sum is", total_sum)
# Out:
# The sum is 42

# %% [markdown]
# **Part B prompt:**
# Write a Python script in a Jupyter Notebook that:
# - Creates two string variables: my first name and my surname
# - Prints them together as my full name
# Use clear variable names and good naming conventions.

# %%
# Part B: Working with strings

first_name = "Swamini"
last_name = "Ektate"

full_name = first_name + " " + last_name

print("Full name:", full_name)
# Out:
# Full name: Swamini Ektate

# %% [markdown]
# **Part C prompt:**
# Write a Python script in a Jupyter Notebook that:
# - Creates an integer variable for my age
# - Prints a sentence in the format: '[Full name] is X years old'
# - Uses the full_name variable already created in Part B
# Use clear variable names and good naming conventions.

# %%
# Part C: Combining types

age = 29

print(full_name + " is " + str(age) + " years old")
# Out:
# Swamini Ektate is 29 years old

# %% [markdown]
# **Stretch goal prompt:**
# Refactor my Parts A, B and C into separate functions called from a main block.
# Add input() so the user can type their own values instead of hardcoded ones.
# Use clear variable names and good naming conventions.

# %% [markdown]
# # Stretch Goals: Functions + User Input
#
# def add_two_integers():
#     first_number = int(input("Enter your first number: "))
#     second_number = int(input("Enter your second number: "))
#     total_sum = first_number + second_number
#     print("The sum is", total_sum)
#
# def print_full_name():
#     first_name = input("Enter your first name: ")
#     last_name = input("Enter your last name: ")
#     full_name = first_name + " " + last_name
#     print("Full name:", full_name)
#     return full_name
#
# def print_age_sentence(full_name):
#     age = int(input("Enter your age: "))
#     print(full_name + " is " + str(age) + " years old")
#
# def main():
#     add_two_integers()
#     full_name = print_full_name()
#     print_age_sentence(full_name)
#
# main()

# %% [markdown]
# ## Reflection
#
# **What was the AI good at?**
# - Generating correct syntax quickly
# - Following naming conventions when asked specifically
# - Structuring the header comment block
#
# **Where did I have to fix things?**
# - Had to check variable names made sense in context
# - Had to make sure full_name was passed correctly between functions
# - Had to verify the output matched the required format exactly
